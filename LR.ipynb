# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('GSE71766.csv', index_col=0)
df.head()
# Out:
#                        H3C8  TNFAIP8L1     OTOP2  C17orf78  LINC01098  \
# GSM1844791.CEL.gz  4.472754   5.757114  3.677292  3.647913   3.275133
# GSM1844792.CEL.gz  4.417698   6.034899  3.472789  3.729788   3.423107
# GSM1844793.CEL.gz  4.466385   5.992671  3.603946  3.718264   3.532478
# GSM1844794.CEL.gz  4.423628   5.856314  3.560481  3.528959   3.418325
# GSM1844795.CEL.gz  4.507583   6.039961  3.656828  3.524553   3.574196
#
#                       SAMD7    ARRDC5    ERICH3  FAM86C1P    H2BC10  ...  \
# GSM1844791.CEL.gz  3.747905  3.561909  3.328561  6.719375  3.114560  ...
# GSM1844792.CEL.gz  3.727085  3.785426  3.508113  6.406214  3.201994  ...
# GSM1844793.CEL.gz  3.673952  3.616854  3.284604  6.547866  3.161317  ...
# GSM1844794.CEL.gz  3.672029  3.642061  3.294800  6.594396  3.173589  ...
# GSM1844795.CEL.gz  3.673777  3.533098  3.421456  6.523388  3.127476  ...
#
#                    PPP1R3B-DT  LOC102724152  LINC00380  LOC102724849  \
# GSM1844791.CEL.gz    3.665203      3.534592   3.499261      4.059905
# GSM1844792.CEL.gz    3.603604      3.321383   3.549841      3.985486
# GSM1844793.CEL.gz    3.794965      3.411154   3.320130      3.949259
# GSM1844794.CEL.gz    3.724687      3.346572   3.694831      4.173841
# GSM1844795.CEL.gz    3.716052      3.424974   3.506083      4.395577
#
#                     IFITM10        ND4  LOC102723906   HSP90AB1      RPS10  \
# GSM1844791.CEL.gz  3.494022  13.666685      3.799392  12.697320  13.271646
# GSM1844792.CEL.gz  3.316881  13.563650      3.729302  12.731006  13.369366
# GSM1844793.CEL.gz  3.556682  13.496680      3.835387  12.665760  13.355950
# GSM1844794.CEL.gz  3.438986  13.579328      3.824968  12.682281  13.329859
# GSM1844795.CEL.gz  3.487639  13.522189      3.798908  12.687768  13.410700
#
#                    stage
# GSM1844791.CEL.gz      1
# GSM1844792.CEL.gz      1
# GSM1844793.CEL.gz      1
# GSM1844794.CEL.gz      1
# GSM1844795.CEL.gz      1
#
# [5 rows x 18450 columns]

# %%
df_label = df[['stage']]
df.drop(columns=['stage'], inplace=True)

# %%
df.head()
# Out:
#                        H3C8  TNFAIP8L1     OTOP2  C17orf78  LINC01098  \
# GSM1844791.CEL.gz  4.472754   5.757114  3.677292  3.647913   3.275133
# GSM1844792.CEL.gz  4.417698   6.034899  3.472789  3.729788   3.423107
# GSM1844793.CEL.gz  4.466385   5.992671  3.603946  3.718264   3.532478
# GSM1844794.CEL.gz  4.423628   5.856314  3.560481  3.528959   3.418325
# GSM1844795.CEL.gz  4.507583   6.039961  3.656828  3.524553   3.574196
#
# 75%      3.706675    3.509460    6.795570    3.226832  ...    3.105096
# max      4.185698    3.784678    7.411749    3.394099  ...    3.448378
#
#        PPP1R3B-DT  LOC102724152   LINC00380  LOC102724849     IFITM10  \
# count  186.000000    186.000000  186.000000    186.000000  186.000000
# mean     3.632448      3.588122    3.582671      4.115877    3.516784
# std      0.160594      0.179457    0.147767      0.176309    0.144890
# min      3.220892      3.185388    3.112316      3.604229    3.009071
# 25%      3.532081      3.457707    3.492861      4.011074    3.413059
# 50%      3.614904      3.573872    3.571058      4.103899    3.516706
# 75%      3.715639      3.697686    3.683648      4.207317    3.602714
# max      4.363774      4.231814    3.959773      4.754262    3.975106
#
#               ND4  LOC102723906    HSP90AB1       RPS10
# count  186.000000    186.000000  186.000000  186.000000
# mean    13.429307      3.798703   12.513946   13.381501
# std      0.064189      0.088769    0.249410    0.047419
# min     13.249496      3.560832   11.818471   13.097470
# 25%     13.383309      3.739483   12.472791   13.351642
# 50%     13.422046      3.798421   12.620612   13.385870
# 75%     13.476871      3.854003   12.675428   13.414748
# max     13.666685      4.144982   12.773908   13.470121
#
# [8 rows x 18449 columns]

# %%
df_label
# Out:
#                    stage
# GSM1844791.CEL.gz      1
# GSM1844792.CEL.gz      1
# GSM1844793.CEL.gz      1
# GSM1844794.CEL.gz      1
# GSM1844795.CEL.gz      1
# ...                  ...
# GSM1844972.CEL.gz      4
# GSM1844973.CEL.gz      4
# GSM1844974.CEL.gz      4
# GSM1844975.CEL.gz      4
# GSM1844976.CEL.gz      4
#
# [186 rows x 1 columns]

# %%
df_label.value_counts()
# Out:
# stage
# 1        51
# 2        45
# 3        45
# 4        45
# Name: count, dtype: int64

# %%
from matplotlib import pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.histplot(data=df_label, x='stage')
plt.title('Distribution of Labels')
plt.xlabel('Class')
plt.ylabel('Frequency')
plt.show()
# Out:
# c:\Users\Yavuz\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df, df_label, test_size=0.2, random_state=0, stratify = df_label)

# %%
print("X_train:", X_train.shape, "X_test", X_test.shape)
print("y_train:", y_train.shape, "y_test", y_test.shape)
# Out:
# X_train: (148, 18449) X_test (38, 18449)
# y_train: (148, 1) y_test (38, 1)

# %%
from sklearn.linear_model import LogisticRegression

# y_train'i sütun vektörüne dönüştürme
y_train_reshaped = y_train.values.ravel()

# Lojistik regresyon sınıflandırıcısını oluşturma
clf = LogisticRegression(max_iter=10000)

# Eğitim setlerini kullanarak modeli eğitme
clf.fit(X_train, y_train_reshaped)

# Test veri kümesi için tahminde bulunma
y_pred = clf.predict(X_test)

# %%
from sklearn import metrics

print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("Macro Precision:",metrics.precision_score(y_test, y_pred,average='macro'))
print("Macro Recall:",metrics.recall_score(y_test, y_pred,average='macro'))
# Out:
# Accuracy: 0.7105263157894737
# Macro Precision: 0.7301510989010989
# Macro Recall: 0.7045454545454545

# %%
target_names = ['Uninfected', 'Influenza virus infected', 'Rhino virus infected','Influenza & Rhino virus infected' ]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#                                   precision    recall  f1-score   support
#
#                       Uninfected       0.90      0.82      0.86        11
#         Influenza virus infected       0.62      0.56      0.59         9
#             Rhino virus infected       0.86      0.67      0.75         9
# Influenza & Rhino virus infected       0.54      0.78      0.64         9
#
#                         accuracy                           0.71        38
#                        macro avg       0.73      0.70      0.71        38
#                     weighted avg       0.74      0.71      0.72        38

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_test, y_pred, labels=clf.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=clf.classes_)
disp.plot()
plt.show()

# %%
# DataFrame'in kopyasını al
df_label_copy = df_label.copy()

# Değerleri güncelle
df_label_copy.loc[df_label_copy["stage"] == 1, "stage"] = 1 # uninfected
df_label_copy.loc[df_label_copy["stage"].isin([2, 3, 4]), "stage"] = 2 # infected

# Sonuçları kontrol et
df_label_copy["stage"].value_counts()
# Out:
# stage
# 2    135
# 1     51
# Name: count, dtype: int64

# %%
# Veri setini eğitim ve test setlerine ayırma
X_train, X_test, y_train, y_test = train_test_split(df, df_label_copy, test_size=0.2, random_state=0, stratify=df_label_copy)

# y_train'i sütun vektörüne dönüştürme
y_train_reshaped = y_train.values.ravel()

# Lojistik regresyon sınıflandırıcısını oluşturma
clf = LogisticRegression(max_iter = 10000)

# Eğitim setlerini kullanarak modeli eğitme
clf.fit(X_train, y_train_reshaped)

# Test veri kümesi için tahminde bulunma
y_pred = clf.predict(X_test)

# Değerlendirme
print(classification_report(y_test, y_pred, target_names=['Uninfected', 'Infected']))
# Out:
#               precision    recall  f1-score   support
#
#   Uninfected       1.00      0.80      0.89        10
#     Infected       0.93      1.00      0.97        28
#
#     accuracy                           0.95        38
#    macro avg       0.97      0.90      0.93        38
# weighted avg       0.95      0.95      0.95        38

# %%
from sklearn.model_selection import cross_val_score

# y_train'i sütun vektörüne dönüştürme
y_train_reshaped = y_train.values.ravel()

scores = cross_val_score(clf, X_train, y_train_reshaped, cv=10)
print("%0.2f accuracy with a standard deviation of %0.2f" % (scores.mean(), scores.std()))
# Out:
# 0.92 accuracy with a standard deviation of 0.07

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# y_train'i sütun vektörüne dönüştürme
y_train_reshaped = y_train.values.ravel()

# Hyperparameter Optimization
parameters = {'C': [0.1, 1, 10]}

log_reg = LogisticRegression(max_iter = 10000)

# Grid aramasını çalıştırma
grid_obj = GridSearchCV(log_reg, parameters, cv=5)
grid_obj = grid_obj.fit(X_train, y_train_reshaped)

# En iyi parametre yapılandırmasını gösterme
best_parameters = grid_obj.best_params_
print(best_parameters)

# En iyi parametre kombinasyonunu belirlemek için clf'yi ayarlama
best_clf = grid_obj.best_estimator_

# Test veri kümesi için tahminde bulunma
y_pred = best_clf.predict(X_test)

# Sınıflandırma raporunu yazdırma
print(classification_report(y_test, y_pred, target_names=['Uninfected', 'Infected']))
# Out:
# {'C': 1}
#               precision    recall  f1-score   support
#
#   Uninfected       1.00      0.80      0.89        10
#     Infected       0.93      1.00      0.97        28
#
#     accuracy                           0.95        38
#    macro avg       0.97      0.90      0.93        38
# weighted avg       0.95      0.95      0.95        38

# %%
cm = confusion_matrix(y_test, y_pred, labels=best_clf.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=best_clf.classes_)
disp.plot()
plt.show()
